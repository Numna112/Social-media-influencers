# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
smi=pd.read_csv("c:\\Users\\Admin\\Desktop\\sminsta.csv")
smt=pd.read_csv('c:\\Users\\Admin\\Desktop\\smtiktok.csv')
smy=pd.read_csv('c:\\Users\\Admin\\Desktop\\smyoutube.csv')

# %%
smi.head()
# Out:
#   Influencer insta name instagram name          category_1 category_2  \
# 0                   433            433  Sports with a ball        NaN
# 1          __youngbae__        TAEYANG               Music        NaN
# 2           _agentgirl_  НАСТЯ ИВЛЕЕВА               Shows        NaN
# 3           _imyour_joy            Joy           Lifestyle        NaN
# 4         _jeongjaehyun        Jaehyun                 NaN        NaN
#
#   Followers Audience country(mostly) Authentic engagement\r\n  \
# 0     48.5M                    Spain                   383.1K
# 1     12.7M                Indonesia                     478K
# 2     18.8M                   Russia                   310.8K
# 3     13.5M                Indonesia                     1.1M
# 4     11.1M                Indonesia                     2.5M
#
#   Engagement avg\r\n
# 0               637K
# 1             542.3K
# 2             377.9K
# 3               1.4M
# 4               3.1M

# %%
smi.shape
# Out:
# (1000, 8)

# %%
smi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Influencer insta name     1000 non-null   object
#  1   instagram name            979 non-null    object
#  2   category_1                892 non-null    object
#  3   category_2                287 non-null    object
#  4   Followers                 1000 non-null   object
#  5   Audience country(mostly)  986 non-null    object
#  6   Authentic engagement
#     1000 non-null   object
#  7   Engagement avg
#           1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
smi.isnull().sum().sort_values(ascending=False)
# Out:
# category_2                  713
# category_1                  108
# instagram name               21
# Audience country(mostly)     14
# Influencer insta name         0
# Followers                     0
# Authentic engagement\r\n      0
# Engagement avg\r\n            0
# dtype: int64

# %%
(smi.isnull().sum())/len(smi)*100
# Out:
# Influencer insta name        0.0
# instagram name               2.1
# category_1                  10.8
# category_2                  71.3
# Followers                    0.0
# Audience country(mostly)     1.4
# Authentic engagement\r\n     0.0
# Engagement avg\r\n           0.0
# dtype: float64

# %%
smi=smi.drop(['category_2','Influencer insta name'],axis=1)
smi
# Out:
#     instagram name                 category_1 Followers  \
# 0              433         Sports with a ball     48.5M
# 1          TAEYANG                      Music     12.7M
# 2    НАСТЯ ИВЛЕЕВА                      Shows     18.8M
# 3              Joy                  Lifestyle     13.5M
# 4          Jaehyun                        NaN     11.1M
# ..             ...                        ...       ...
# 995        Zendaya  Cinema & Actors/actresses    136.1M
# 996         zidane         Sports with a ball     31.2M
# 997            KAI                      Music     13.9M
# 998   Zoë Kravitz  Cinema & Actors/actresses      8.2M
# 999      Zoë Sugg                  Lifestyle      9.4M
#
#     Audience country(mostly) Authentic engagement\r\n Engagement avg\r\n
# 0                      Spain                   383.1K               637K
# 1                  Indonesia                     478K             542.3K
# ...

# %%
(smi.isnull().sum())/len(smi)*100
# Out:
# instagram name               2.1
# category_1                  10.8
# Followers                    0.0
# Audience country(mostly)     1.4
# Authentic engagement\r\n     0.0
# Engagement avg\r\n           0.0
# dtype: float64

# %%
smi['category_1'].unique()
# Out:
# array(['Sports with a ball', 'Music', 'Shows', 'Lifestyle', nan,
#        'Humor & Fun & Happiness', 'Cinema & Actors/actresses', 'Beauty',
#        'Clothing & Outfits', 'Fashion', 'Modeling', 'Food & Cooking',
#        'Family', 'Fitness & Gym', 'Computers & Gadgets', 'Art/Artists',
#        'Finance & Economics', 'Cars & Motorbikes', 'Photography',
#        'Racing Sports', 'Literature & Journalism', 'Business & Careers',
#        'Animals', 'Nature & landscapes', 'Adult content',
#        'Accessories & Jewellery', 'Education', 'Management & Marketing',
#        'Luxury', 'Science', 'Machinery & Technologies', 'Kids & Toys'],
#       dtype=object)

# %%
smi['category_1'].value_counts()
# Out:
# Music                        235
# Cinema & Actors/actresses    214
# Sports with a ball           113
# Lifestyle                     99
# Shows                         43
# Modeling                      36
# Beauty                        28
# Humor & Fun & Happiness       18
# Art/Artists                   12
# Family                        11
# Fitness & Gym                 10
# Fashion                        9
# Computers & Gadgets            9
# Racing Sports                  7
# Adult content                  6
# Cars & Motorbikes              5
# Finance & Economics            5
# Clothing & Outfits             5
# Photography                    4
# Business & Careers             4
# Food & Cooking                 3
# Literature & Journalism        3
# Nature & landscapes            3
# Management & Marketing         2
# Science                        2
# Animals                        1
# Accessories & Jewellery        1
# Education                      1
# ...

# %%
smi['category_1']=smi['category_1'].replace(np.nan,'Music')

# %%
smi['category_1']
# Out:
# 0             Sports with a ball
# 1                          Music
# 2                          Shows
# 3                      Lifestyle
# 4                          Music
#                  ...
# 995    Cinema & Actors/actresses
# 996           Sports with a ball
# 997                        Music
# 998    Cinema & Actors/actresses
# 999                    Lifestyle
# Name: category_1, Length: 1000, dtype: object

# %%
(smi.isnull().sum())/len(smi)*100
# Out:
# instagram name              2.1
# category_1                  0.0
# Followers                   0.0
# Audience country(mostly)    1.4
# Authentic engagement\r\n    0.0
# Engagement avg\r\n          0.0
# dtype: float64

# %%
smi['Audience country(mostly)'].unique()
# Out:
# array(['Spain', 'Indonesia', 'Russia', 'Brazil', 'Poland', 'South Korea',
#        'United States', 'Thailand', 'India', 'Iraq', 'Morocco', 'Turkey',
#        nan, 'Mexico', 'Chile', 'Iran', 'Italy', 'Colombia', 'Argentina',
#        'Philippines', 'United Kingdom', 'Germany', 'Nigeria', 'Serbia',
#        'Albania', 'United Arab Emirates', 'China', 'France', 'Japan',
#        'Egypt', 'Syria', 'Algeria', 'Ukraine'], dtype=object)

# %%
smi['Audience country(mostly)'].value_counts()
# Out:
# United States           279
# Brazil                  152
# India                   149
# Indonesia               134
# Mexico                   45
# Spain                    34
# Russia                   24
# Argentina                23
# Iran                     23
# United Kingdom           20
# Turkey                   16
# Italy                    13
# Colombia                 13
# South Korea              13
# Philippines               7
# France                    6
# Thailand                  6
# Iraq                      5
# Egypt                     5
# Germany                   3
# Morocco                   3
# Nigeria                   2
# Japan                     2
# Chile                     1
# Algeria                   1
# Syria                     1
# Serbia                    1
# China                     1
# United Arab Emirates      1
# Albania                   1
# Poland                    1
# Ukraine                   1
# ...

# %%
smi['Audience country(mostly)']=smi['Audience country(mostly)'].replace(np.nan,'United States')

# %%
smi['Audience country(mostly)']
# Out:
# 0               Spain
# 1           Indonesia
# 2              Russia
# 3           Indonesia
# 4           Indonesia
#             ...
# 995     United States
# 996             Spain
# 997         Indonesia
# 998     United States
# 999    United Kingdom
# Name: Audience country(mostly), Length: 1000, dtype: object

# %%
smi.rename(columns={'instagram name':'insta_name','category_1':
                    'cat_1','Followers':'insta_foll','Audience country(mostly)':"Audience_insta",
                    'Authentic engagement\r\n':'Authentic_insta','Engagement avg\r\n':'Engagement_avg_insta'},inplace=True)

# %%
smi.head()
# Out:
#       insta_name               cat_1 insta_foll Audience_insta  \
# 0            433  Sports with a ball      48.5M          Spain
# 1        TAEYANG               Music      12.7M      Indonesia
# 2  НАСТЯ ИВЛЕЕВА               Shows      18.8M         Russia
# 3            Joy           Lifestyle      13.5M      Indonesia
# 4        Jaehyun               Music      11.1M      Indonesia
#
#   Authentic_insta Engagement_avg_insta
# 0          383.1K                 637K
# 1            478K               542.3K
# 2          310.8K               377.9K
# 3            1.1M                 1.4M
# 4            2.5M                 3.1M

# %%
smi['insta_foll']=smi['insta_foll'].replace({'M' :"*1e6"},regex=True).map(pd.eval).astype(int)
smi['insta_foll']
# Out:
# 0       48500000
# 1       12700000
# 2       18800000
# 3       13500000
# 4       11100000
#          ...
# 995    136100000
# 996     31200000
# 997     13900000
# 998      8199999
# 999      9400000
# Name: insta_foll, Length: 1000, dtype: int32

# %%
smi['Authentic_insta']=smi['Authentic_insta'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smi['Authentic_insta']
# Out:
# 0       383100
# 1       478000
# 2       310800
# 3      1100000
# 4      2500000
#         ...
# 995    6400000
# 996     546000
# 997    1300000
# 998     583000
# 999     208700
# Name: Authentic_insta, Length: 1000, dtype: int32

# %%
smi['Engagement_avg_insta']=smi['Engagement_avg_insta'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smi['Engagement_avg_insta']
# Out:
# 0       637000
# 1       542300
# 2       377900
# 3      1400000
# 4      3100000
#         ...
# 995    8600000
# 996     744100
# 997    1600000
# 998     885500
# 999     289300
# Name: Engagement_avg_insta, Length: 1000, dtype: int32

# %%
smi.head()
# Out:
#       insta_name               cat_1  insta_foll Audience_insta  \
# 0            433  Sports with a ball    48500000          Spain
# 1        TAEYANG               Music    12700000      Indonesia
# 2  НАСТЯ ИВЛЕЕВА               Shows    18800000         Russia
# 3            Joy           Lifestyle    13500000      Indonesia
# 4        Jaehyun               Music    11100000      Indonesia
#
#    Authentic_insta  Engagement_avg_insta
# 0           383100                637000
# 1           478000                542300
# 2           310800                377900
# 3          1100000               1400000
# 4          2500000               3100000

# %%
smt.head()
# Out:
#     Tiktoker name          Tiktok name Subscribers count Views avg. Likes avg  \
# 0        ekin.721               MOMO’s            221.7K        26M      2.8M
# 1         dojacat             Doja Cat             22.2M      25.4M        5M
# 2     kiet.ac.quy           Kiệt Ắk Wỷ              2.1M      20.7M      3.5M
# 3   charlidamelio      charli d’amelio            135.4M      18.7M      2.6M
# 4  luvadepedreiro  Iran Ferreira (Lai)             11.4M      24.8M      2.6M
#
#   Comments avg. Shares avg
# 0         29.4K     116.4K
# 1         36.7K      46.8K
# 2         38.8K      33.9K
# 3         54.7K      35.2K
# 4         32.7K      26.8K

# %%
smt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tiktoker name      1000 non-null   object
#  1   Tiktok name        998 non-null    object
#  2   Subscribers count  1000 non-null   object
#  3   Views avg.         1000 non-null   object
#  4   Likes avg          1000 non-null   object
#  5   Comments avg.      1000 non-null   object
#  6   Shares avg         1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %%
del smt ['Tiktok name']

# %%
smt
# Out:
#        Tiktoker name Subscribers count Views avg. Likes avg Comments avg.  \
# 0           ekin.721            221.7K        26M      2.8M         29.4K
# 1            dojacat             22.2M      25.4M        5M         36.7K
# 2        kiet.ac.quy              2.1M      20.7M      3.5M         38.8K
# 3      charlidamelio            135.4M      18.7M      2.6M         54.7K
# 4     luvadepedreiro             11.4M      24.8M      2.6M         32.7K
# ..               ...               ...        ...       ...           ...
# 995    nicolebernaal                4M       2.2M    351.3K           957
# 996    bellaretamosa              5.1M       2.5M    340.4K           901
# 997         tunico80              5.8M         1M    206.8K            2K
# 998     armon.warren              1.2M       1.9M    300.8K           904
# 999  soanhvadiephihi              1.6M       2.6M    273.2K           720
#
#     Shares avg
# 0       116.4K
# 1        46.8K
# 2        33.9K
# ...

# %%
smt.head()
# Out:
#     Tiktoker name Subscribers count Views avg. Likes avg Comments avg.  \
# 0        ekin.721            221.7K        26M      2.8M         29.4K
# 1         dojacat             22.2M      25.4M        5M         36.7K
# 2     kiet.ac.quy              2.1M      20.7M      3.5M         38.8K
# 3   charlidamelio            135.4M      18.7M      2.6M         54.7K
# 4  luvadepedreiro             11.4M      24.8M      2.6M         32.7K
#
#   Shares avg
# 0     116.4K
# 1      46.8K
# 2      33.9K
# 3      35.2K
# 4      26.8K

# %%
smt.rename(columns={'Subscribers count':'sub_count_tik','Views avg.'
                    :'avg_views_tik','Likes avg':"avg_likes_tik",'Comments avg.'
                    :'Com_avg_tik','Shares avg':'Shares_avg_tik'},inplace=True)

# %%
smt['sub_count_tik']=smt['sub_count_tik'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smt['sub_count_tik']
# Out:
# 0         221700
# 1       22200000
# 2        2100000
# 3      135400000
# 4       11400000
#          ...
# 995      4000000
# 996      5100000
# 997      5800000
# 998      1200000
# 999      1600000
# Name: sub_count_tik, Length: 1000, dtype: int32

# %%
smt['avg_views_tik']=smt['avg_views_tik'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smt['avg_views_tik']
# Out:
# 0      26000000
# 1      25400000
# 2      20700000
# 3      18700000
# 4      24800000
#          ...
# 995     2200000
# 996     2500000
# 997     1000000
# 998     1900000
# 999     2600000
# Name: avg_views_tik, Length: 1000, dtype: int32

# %%
smt['avg_likes_tik']=smt['avg_likes_tik'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smt['avg_likes_tik']
# Out:
# 0      2800000
# 1      5000000
# 2      3500000
# 3      2600000
# 4      2600000
#         ...
# 995     351300
# 996     340400
# 997     206800
# 998     300800
# 999     273200
# Name: avg_likes_tik, Length: 1000, dtype: int32

# %%
smt['Com_avg_tik']=smt['Com_avg_tik'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smt['Com_avg_tik']
# Out:
# 0      29400
# 1      36700
# 2      38800
# 3      54700
# 4      32700
#        ...
# 995      957
# 996      901
# 997     2000
# 998      904
# 999      720
# Name: Com_avg_tik, Length: 1000, dtype: int32

# %%
smt['Shares_avg_tik']=smt['Shares_avg_tik'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smt['Shares_avg_tik']
# Out:
# 0      116400
# 1       46800
# 2       33900
# 3       35200
# 4       26800
#         ...
# 995       195
# 996       145
# 997      2100
# 998       630
# 999       530
# Name: Shares_avg_tik, Length: 1000, dtype: int32

# %%
smt.head()
# Out:
#     Tiktoker name  sub_count_tik  avg_views_tik  avg_likes_tik  Com_avg_tik  \
# 0        ekin.721         221700       26000000        2800000        29400
# 1         dojacat       22200000       25400000        5000000        36700
# 2     kiet.ac.quy        2100000       20700000        3500000        38800
# 3   charlidamelio      135400000       18700000        2600000        54700
# 4  luvadepedreiro       11400000       24800000        2600000        32700
#
#    Shares_avg_tik
# 0          116400
# 1           46800
# 2           33900
# 3           35200
# 4           26800

# %%
smy.head()
# Out:
#   youtuber name                channel name       Category Subscribers  \
# 0       tseries                    T-Series  Music & Dance      212.1M
# 1     checkgate  Cocomelon - Nursery Rhymes      Education      132.1M
# 2      setindia                   SET India            NaN      130.4M
# 3     PewDiePie                   PewDiePie      Animation      111.4M
# 4   MrBeast6000                     MrBeast    Video games       92.5M
#
#   Audience Country avg views avg likes avg comments
# 0            India    323.7K      9.8K          290
# 1              NaN     13.8M     80.9K          NaN
# 2            India     23.6K       314           21
# 3    United States      1.4M     80.8K         4.6K
# 4    United States     30.6M      1.7M        67.7K

# %%
smy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   youtuber name     1000 non-null   object
#  1   channel name      1000 non-null   object
#  2   Category          723 non-null    object
#  3   Subscribers       1000 non-null   object
#  4   Audience Country  839 non-null    object
#  5   avg views         1000 non-null   object
#  6   avg likes         962 non-null    object
#  7   avg comments      791 non-null    object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
smy.isnull().sum()
# Out:
# youtuber name         0
# channel name          0
# Category            277
# Subscribers           0
# Audience Country    161
# avg views             0
# avg likes            38
# avg comments        209
# dtype: int64

# %%
smy['Category'].unique()
# Out:
# array(['Music & Dance', 'Education', nan, 'Animation', 'Video games',
#        'Toys', 'Movies', 'News & Politics', 'Daily vlogs', 'Humor',
#        'Beauty', 'Design/art', 'Fitness', 'DIY & Life Hacks',
#        'Food & Drinks', 'Sports', 'ASMR', 'Science & Technology',
#        'Fashion', 'Health & Self Help', 'Autos & Vehicles',
#        'Animals & Pets', 'Mystery', 'Travel'], dtype=object)

# %%
smy['Category'].value_counts()
# Out:
# Music & Dance           224
# Animation                97
# Video games              84
# News & Politics          49
# Toys                     45
# Movies                   38
# Daily vlogs              35
# Education                33
# Humor                    30
# Science & Technology     17
# Food & Drinks            16
# DIY & Life Hacks         15
# Sports                   11
# Fashion                   7
# Animals & Pets            4
# Design/art                4
# Fitness                   3
# ASMR                      3
# Health & Self Help        2
# Autos & Vehicles          2
# Beauty                    2
# Mystery                   1
# Travel                    1
# Name: Category, dtype: int64

# %%
smy['Category']=smy['Category'].replace(np.nan,'Music & Dance ')
smy['Category']
# Out:
# 0       Music & Dance
# 1           Education
# 2      Music & Dance
# 3           Animation
# 4         Video games
#             ...
# 995     Music & Dance
# 996              Toys
# 997            Movies
# 998            Sports
# 999         Animation
# Name: Category, Length: 1000, dtype: object

# %%
smy['Audience Country'].unique()
# Out:
# array(['India', nan, 'United States', 'Brazil', 'Mexico', 'Russia',
#        'Philippines', 'Argentina', 'Thailand', 'France', 'Colombia',
#        'Indonesia', 'Pakistan', 'Ecuador', 'Iraq', 'Turkey',
#        'Saudi Arabia', 'Spain', 'Algeria', 'Egypt', 'Japan', 'Bangladesh',
#        'United Kingdom', 'Poland', 'Singapore', 'Peru', 'Cyprus',
#        'Morocco'], dtype=object)

# %%
smy['Audience Country'].value_counts()
# Out:
# United States     291
# India             208
# Brazil             92
# Mexico             64
# Indonesia          38
# Russia             33
# Thailand           18
# Philippines        16
# Colombia           10
# Iraq               10
# Egypt               8
# Argentina           7
# Pakistan            6
# United Kingdom      5
# Saudi Arabia        5
# Spain               5
# Bangladesh          3
# Japan               3
# France              3
# Algeria             3
# Turkey              3
# Peru                2
# Morocco             2
# Ecuador             1
# Poland              1
# Singapore           1
# Cyprus              1
# Name: Audience Country, dtype: int64

# %%
smy['Audience Country']=smy['Audience Country'].replace(np.nan,'United States')
smy['Audience Country']
# Out:
# 0              India
# 1      United States
# 2              India
# 3      United States
# 4      United States
#            ...
# 995           Brazil
# 996           Brazil
# 997    United States
# 998            India
# 999           Brazil
# Name: Audience Country, Length: 1000, dtype: object

# %%
(smy.isnull().sum())/len(smy)*100
# Out:
# youtuber name        0.0
# channel name         0.0
# Category             0.0
# Subscribers          0.0
# Audience Country     0.0
# avg views            0.0
# avg likes            3.8
# avg comments        20.9
# dtype: float64

# %%
smy['avg likes'].unique()
# Out:
# array(['9.8K', '80.9K', '314', '80.8K', '1.7M', '46.8K', '74.2K', '2.8K',
#        '4.2K', '42.2K', '2.1K', '162.7K', '1K', '2.3K', '598.9K', '899',
#        '62.3K', '1.8K', '631', '375.7K', '1.4K', '5.4K', '47.4K', '290',
#        '128', '2.6K', '7.4K', '1.2K', '129', '140.7K', '5.5K', '149.7K',
#        '34K', '17K', '1.9K', '10.7K', '129K', '4.7K', '12.9K', '136',
#        '3.5K', '650.5K', '26', '3K', '74.6K', '1.6K', '944', '7.8K',
#        '11.4K', '13.3K', '790', '646.5K', '604', '174.6K', '17.2K', '139',
#        '2.9K', '52.4K', '4.5K', '3.7K', '103.3K', nan, '133', '31.7K',
#        '7.5K', '2K', '515', '165.3K', '1.7K', '4.4K', '35', '19.7K',
#        '396.4K', '25.8K', '140K', '22.1K', '570', '141.9K', '277.4K',
#        '2.4K', '65.8K', '2.7K', '220', '219', '3.1K', '54.7K', '2.2K',
#        '43.2K', '51.6K', '28.7K', '81.1K', '2.5K', '530', '109', '67',
#        '63.2K', '127.6K', '25.3K', '95.8K', '9K', '5.1K', '143', '906',
# ...

# %%
smy['avg likes'].value_counts()
# Out:
# 1.2K    17
# 1.6K    13
# 2.2K    13
# 1.4K    11
# 1.8K    10
#         ..
# 35K      1
# 957      1
# 104K     1
# 507      1
# 854      1
# Name: avg likes, Length: 615, dtype: int64

# %%
smy['avg likes']=smy['avg likes'].replace(np.nan,'1200')
smy['avg likes']
# Out:
# 0        9.8K
# 1       80.9K
# 2         314
# 3       80.8K
# 4        1.7M
#         ...
# 995    110.1K
# 996     30.7K
# 997     10.2K
# 998       854
# 999      9.8K
# Name: avg likes, Length: 1000, dtype: object

# %%
(smy.isnull().sum())/len(smy)*100
# Out:
# youtuber name        0.0
# channel name         0.0
# Category             0.0
# Subscribers          0.0
# Audience Country     0.0
# avg views            0.0
# avg likes            0.0
# avg comments        20.9
# dtype: float64

# %%
smy['avg likes']=smy['avg likes'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smy['avg likes']
# Out:
# 0         9800
# 1        80900
# 2          314
# 3        80800
# 4      1700000
#         ...
# 995     110100
# 996      30700
# 997      10200
# 998        854
# 999       9800
# Name: avg likes, Length: 1000, dtype: int32

# %%
smy.head()
# Out:
#   youtuber name                channel name        Category Subscribers  \
# 0       tseries                    T-Series   Music & Dance      212.1M
# 1     checkgate  Cocomelon - Nursery Rhymes       Education      132.1M
# 2      setindia                   SET India  Music & Dance       130.4M
# 3     PewDiePie                   PewDiePie       Animation      111.4M
# 4   MrBeast6000                     MrBeast     Video games       92.5M
#
#   Audience Country avg views  avg likes avg comments
# 0            India    323.7K       9800          290
# 1    United States     13.8M      80900          NaN
# 2            India     23.6K        314           21
# 3    United States      1.4M      80800         4.6K
# 4    United States     30.6M    1700000        67.7K

# %%
smy.rename(columns={'youtuber name':'youtuber','channel name'
                    :'channel_name','Category':"Cat_youtube",'Subscribers'
                    :'sub_youtube','Audience Country':'Audience_Country_youtube','avg views':'avg_views_youtube',
                   'avg likes':'avg_likes_youtube','avg comments':'avg_comments_youtube'},inplace=True)

# %%
smy.head()
# Out:
#       youtuber                channel_name     Cat_youtube sub_youtube  \
# 0      tseries                    T-Series   Music & Dance      212.1M
# 1    checkgate  Cocomelon - Nursery Rhymes       Education      132.1M
# 2     setindia                   SET India  Music & Dance       130.4M
# 3    PewDiePie                   PewDiePie       Animation      111.4M
# 4  MrBeast6000                     MrBeast     Video games       92.5M
#
#   Audience_Country_youtube avg_views_youtube  avg_likes_youtube  \
# 0                    India            323.7K               9800
# 1            United States             13.8M              80900
# 2                    India             23.6K                314
# 3            United States              1.4M              80800
# 4            United States             30.6M            1700000
#
#   avg_comments_youtube
# 0                  290
# 1                  NaN
# 2                   21
# 3                 4.6K
# 4                67.7K

# %%
smy['sub_youtube'].unique()
# Out:
# array(['212.1M', '132.1M', '130.4M', '111.4M', '92.5M', '92.4M', '90.1M',
#        '86.9M', '82.7M', '80.4M', '76.2M', '68.1M', '67.9M', '65.5M',
#        '65M', '64.9M', '64.7M', '61.5M', '59.2M', '57.4M', '56.6M',
#        '55.2M', '55M', '51.5M', '51.2M', '50.9M', '50.3M', '49.9M',
#        '48.9M', '48.7M', '48.3M', '45.5M', '45.3M', '45.1M', '44M',
#        '43.8M', '43.2M', '42.6M', '41.6M', '41.2M', '40.8M', '40M', '39M',
#        '38.8M', '38.7M', '38.4M', '38.2M', '37.4M', '37.2M', '37.1M',
#        '36.5M', '36M', '35.8M', '35.6M', '35.1M', '34.9M', '34.5M',
#        '33.7M', '33.3M', '32.9M', '32.8M', '32.7M', '32.5M', '32.3M',
#        '32.1M', '31.9M', '31.7M', '31.5M', '31.3M', '31M', '30.9M',
#        '30.7M', '30.5M', '30.4M', '30.3M', '30.2M', '30.1M', '29.7M',
#        '29.6M', '29.5M', '29.3M', '28.9M', '28.8M', '28.6M', '28.5M',
#        '28.3M', '28.2M', '28.1M', '27.7M', '27.5M', '27.4M', '27.3M',
# ...

# %%
smy['sub_youtube']=smy['sub_youtube'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smy['sub_youtube']
# Out:
# 0      212100000
# 1      132100000
# 2      130400000
# 3      111400000
# 4       92500000
#          ...
# 995      9200000
# 996      9200000
# 997      9200000
# 998      9200000
# 999      9200000
# Name: sub_youtube, Length: 1000, dtype: int32

# %%
smy['avg_views_youtube']=smy['avg_views_youtube'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smy['avg_views_youtube']
# Out:
# 0        323700
# 1      13800000
# 2         23600
# 3       1400000
# 4      30600000
#          ...
# 995     1400000
# 996      243800
# 997      296000
# 998       15200
# 999      112300
# Name: avg_views_youtube, Length: 1000, dtype: int32

# %%
smy['avg_comments_youtube'].unique()
# Out:
# array(['290', nan, '21', '4.6K', '67.7K', '163', '155', '68', '7.9K',
#        '39', '153', '14.2K', '27', '2.6K', '17', '33', '9.1K', '4.9K',
#        '8', '10', '75', '85', '73', '14', '4.8K', '104', '7.2K', '245',
#        '145', '137', '824', '2.7K', '378', '19', '79', '43.9K', '1',
#        '3.3K', '54', '190', '59', '42.3K', '18', '15.8K', '7', '1.4K',
#        '4', '256', '22', '6K', '3', '1.2K', '143.6K', '1K', '6.8K', '24',
#        '64', '7.3K', '9.6K', '83', '931', '131', '136', '11', '31',
#        '3.2K', '69', '1.8K', '463', '4.4K', '71', '121', '6', '2K', '48',
#        '5.2K', '1.1K', '112', '3.6K', '5', '129', '44K', '240', '12',
#        '3.7K', '267', '624', '235', '997', '25.8K', '57', '382', '1.5K',
#        '80', '231', '749', '18.9K', '18.4K', '2.2K', '358', '8.9K', '36',
#        '3.9K', '675', '325', '783', '107', '773', '450', '188', '879',
#        '8.1K', '2.3K', '130', '97', '847', '2', '373', '1.7K', '626',
# ...

# %%
smy['avg_comments_youtube'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        290
# 1        NaN
# 2         21
# 3       4.6K
# 4      67.7K
#        ...
# 995     2.5K
# 996      636
# 997      874
# 998       58
# 999      246
# Name: avg_comments_youtube, Length: 1000, dtype: object>

# %%
smy['avg_comments_youtube']=smy['avg_comments_youtube'].replace(np.nan,'0')

# %%
smy['avg_comments_youtube']=smy['avg_comments_youtube'].replace({'K' :"*1e3",'M':'*1e6'},regex=True).map(pd.eval).astype(int)
smy['avg_comments_youtube']
# Out:
# 0        290
# 1          0
# 2         21
# 3       4600
# 4      67700
#        ...
# 995     2500
# 996      636
# 997      874
# 998       58
# 999      246
# Name: avg_comments_youtube, Length: 1000, dtype: int32

# %%
smy['avg_comments_youtube'].sort_values(ascending=False)
# Out:
# 503    313600
# 76     143600
# 924    139800
# 703     94300
# 844     89400
#         ...
# 852         0
# 854         0
# 649         0
# 226         0
# 182         0
# Name: avg_comments_youtube, Length: 1000, dtype: int32

# %%
smy['avg_comments_youtube'].describe()
# Out:
# count      1000.000000
# mean       2648.978000
# std       13653.462037
# min           0.000000
# 25%           8.000000
# 50%         135.500000
# 75%        1100.000000
# max      313600.000000
# Name: avg_comments_youtube, dtype: float64

# %%
smy['avg_comments_youtube']=smy['avg_comments_youtube'].fillna(smy['avg_comments_youtube'].mean())

# %%
smy['avg_comments_youtube']
# Out:
# 0        290
# 1          0
# 2         21
# 3       4600
# 4      67700
#        ...
# 995     2500
# 996      636
# 997      874
# 998       58
# 999      246
# Name: avg_comments_youtube, Length: 1000, dtype: int32

# %%
(smy.isnull().sum())/len(smy)*100
# Out:
# youtuber                    0.0
# channel_name                0.0
# Cat_youtube                 0.0
# sub_youtube                 0.0
# Audience_Country_youtube    0.0
# avg_views_youtube           0.0
# avg_likes_youtube           0.0
# avg_comments_youtube        0.0
# dtype: float64

# %%
df=pd.concat([smi,smt,smy],axis=1)
df
# Out:
#         insta_name                      cat_1  insta_foll  Audience_insta  \
# 0              433         Sports with a ball    48500000           Spain
# 1          TAEYANG                      Music    12700000       Indonesia
# 2    НАСТЯ ИВЛЕЕВА                      Shows    18800000          Russia
# 3              Joy                  Lifestyle    13500000       Indonesia
# 4          Jaehyun                      Music    11100000       Indonesia
# ..             ...                        ...         ...             ...
# 995        Zendaya  Cinema & Actors/actresses   136100000   United States
# 996         zidane         Sports with a ball    31200000           Spain
# 997            KAI                      Music    13900000       Indonesia
# 998   Zoë Kravitz  Cinema & Actors/actresses     8199999   United States
# 999      Zoë Sugg                  Lifestyle     9400000  United Kingdom
#
#      Authentic_insta  Engagement_avg_insta    Tiktoker name  sub_count_tik  \
# ...

# %%
(df.isnull().sum())/len(df)*100
# Out:
# insta_name                  2.1
# cat_1                       0.0
# insta_foll                  0.0
# Audience_insta              0.0
# Authentic_insta             0.0
# Engagement_avg_insta        0.0
# Tiktoker name               0.0
# sub_count_tik               0.0
# avg_views_tik               0.0
# avg_likes_tik               0.0
# Com_avg_tik                 0.0
# Shares_avg_tik              0.0
# youtuber                    0.0
# channel_name                0.0
# Cat_youtube                 0.0
# sub_youtube                 0.0
# Audience_Country_youtube    0.0
# avg_views_youtube           0.0
# avg_likes_youtube           0.0
# avg_comments_youtube        0.0
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.groupby('Audience_insta').Audience_insta.count().sort_values(ascending=False)
# Out:
# Audience_insta
# United States           293
# Brazil                  152
# India                   149
# Indonesia               134
# Mexico                   45
# Spain                    34
# Russia                   24
# Argentina                23
# Iran                     23
# United Kingdom           20
# Turkey                   16
# Italy                    13
# South Korea              13
# Colombia                 13
# Philippines               7
# France                    6
# Thailand                  6
# Egypt                     5
# Iraq                      5
# Germany                   3
# Morocco                   3
# Nigeria                   2
# Japan                     2
# Ukraine                   1
# United Arab Emirates      1
# China                     1
# Syria                     1
# Serbia                    1
# Poland                    1
# Algeria                   1
# Chile                     1
# Albania                   1
# ...

# %%
df[df['insta_foll']>100000].sort_values(by='insta_foll',ascending=False).head(10)
# Out:
#             insta_name                      cat_1  insta_foll Audience_insta  \
# 388          Instagram                Photography   487200000          India
# 203  Cristiano Ronaldo         Sports with a ball   419600000          India
# 510            Kylie 🤍                    Fashion   323300000  United States
# 532          Leo Messi         Sports with a ball   315400000      Argentina
# 814       Selena Gomez                      Music   308200000  United States
# 899            therock  Cinema & Actors/actresses   307000000          India
# 87       Ariana Grande                      Music   302300000  United States
# 494     Kim Kardashian                    Fashion   296400000  United States
# 126           Beyoncé                      Music   246900000  United States
# 489  Khloé Kardashian         Clothing & Outfits   230200000  United States
#
#      Authentic_insta  Engagement_avg_insta        Tiktoker name  \
# ...

# %%
df['insta_foll'].describe()
# Out:
# count    1.000000e+03
# mean     2.571620e+07
# std      4.102903e+07
# min      2.600000e+06
# 25%      9.000000e+06
# 50%      1.455000e+07
# 75%      2.652500e+07
# max      4.872000e+08
# Name: insta_foll, dtype: float64

# %%
x=df['Audience_insta']
y=df['insta_foll']
plt.xlim=(0,20)
plt.ylim=(0,20000)
plt.bar(x,y,width=0.3)
# Out:
# <BarContainer object of 1000 artists>

# %%
sns.distplot(df['insta_foll'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='insta_foll', ylabel='Density'>

# %%
sns.kdeplot(df['insta_foll'])
# Out:
# <AxesSubplot:xlabel='insta_foll', ylabel='Density'>

# %%
df.corr()
# Out:
#                       insta_foll  Authentic_insta  Engagement_avg_insta  \
# insta_foll              1.000000         0.245424              0.268244
# Authentic_insta         0.245424         1.000000              0.965709
# Engagement_avg_insta    0.268244         0.965709              1.000000
# sub_count_tik          -0.012252        -0.008742             -0.012272
# avg_views_tik          -0.002238        -0.006911             -0.005929
# avg_likes_tik          -0.041337        -0.005998             -0.013327
# Com_avg_tik            -0.048005         0.020573              0.005121
# Shares_avg_tik         -0.016173         0.014492              0.008278
# sub_youtube            -0.031036        -0.005283             -0.012763
# avg_views_youtube      -0.025338        -0.009737             -0.008988
# avg_likes_youtube      -0.010970        -0.006875             -0.006155
# avg_comments_youtube   -0.022936        -0.016575             -0.017518
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sorted_by_subscribers_df=df.sort_values(by='sub_youtube')

# %%
sorted_by_subscribers_df
# Out:
#         insta_name               cat_1  insta_foll  Audience_insta  \
# 999      Zoë Sugg           Lifestyle     9400000  United Kingdom
# 985           KYUM               Music    10800000        Thailand
# 986   Caresha ..💗💋           Lifestyle     5300000   United States
# 987        YUTA 悠太               Music     7900000       Indonesia
# 988           𝓨𝒖𝒚𝒂            Modeling    17100000          Mexico
# ..             ...                 ...         ...             ...
# 4          Jaehyun               Music    11100000       Indonesia
# 3              Joy           Lifestyle    13500000       Indonesia
# 2    НАСТЯ ИВЛЕЕВА               Shows    18800000          Russia
# 1          TAEYANG               Music    12700000       Indonesia
# 0              433  Sports with a ball    48500000           Spain
#
#      Authentic_insta  Engagement_avg_insta    Tiktoker name  sub_count_tik  \
# 999           208700                289300  soanhvadiephihi        1600000
# ...

# %%
sorted_by_insta_foll_df=df.sort_values(by='insta_foll')

# %%
sorted_by_insta_foll_df
# Out:
#             insta_name               cat_1  insta_foll Audience_insta  \
# 26                 NaN               Music     2600000  United States
# 337            HAECHAN               Music     2700000  United States
# 7     설인아 sᴇᴏʀɪɴᴀ           Lifestyle     3000000    South Korea
# 316     GeorgeNotFound               Music     3100000  United States
# 954        Wilbur Soot               Music     3200000  United States
# ..                 ...                 ...         ...            ...
# 814       Selena Gomez               Music   308200000  United States
# 532          Leo Messi  Sports with a ball   315400000      Argentina
# 510            Kylie 🤍             Fashion   323300000  United States
# 203  Cristiano Ronaldo  Sports with a ball   419600000          India
# 388          Instagram         Photography   487200000          India
#
#      Authentic_insta  Engagement_avg_insta     Tiktoker name  sub_count_tik  \
# ...

# %%
sorted_by_sub_count_tik_df=df.sort_values(by='sub_count_tik')

# %%
sorted_by_sub_count_tik_df
# Out:
#               insta_name                      cat_1  insta_foll  \
# 427         Jessica Jane                  Lifestyle     6000000
# 835  숮이  💄💅👡👠🎀👙🌂👗🌂🎀💋💌         Clothing & Outfits    17500000
# 511          Song hyekyo  Cinema & Actors/actresses    12900000
# 750        RAFA KALIMANN                   Modeling    22800000
# 573        Iran Ferreira                      Music     9500000
# ..                   ...                        ...         ...
# 63        Angelina Jolie                      Music    12600000
# 27          aespa 에스파                      Music     8300000
# 31          Akshay Kumar  Cinema & Actors/actresses    61100000
# 6     Robert Lewandowski         Sports with a ball    25000000
# 3                    Joy                  Lifestyle    13500000
#
#     Audience_insta  Authentic_insta  Engagement_avg_insta   Tiktoker name  \
# 427      Indonesia           441400                582300       ermmm.umm
# ...

# %%
sorted_by_Shares_avg_tik_df=df.sort_values(by='Shares_avg_tik')

# %%
sorted_by_Shares_avg_tik_df
# Out:
#           insta_name                      cat_1  insta_foll Audience_insta  \
# 360   Hrithik Roshan  Cinema & Actors/actresses    41900000          India
# 764       Stray Kids                      Music    20100000      Indonesia
# 996           zidane         Sports with a ball    31200000          Spain
# 763  Shadmehr Aghili                      Music     7600000           Iran
# 995          Zendaya  Cinema & Actors/actresses   136100000  United States
# ..               ...                        ...         ...            ...
# 8     SHOTARO ショウタロウ                      Music     4900000      Indonesia
# 16           AboFlah    Humor & Fun & Happiness     7200000           Iraq
# 1            TAEYANG                      Music    12700000      Indonesia
# 0                433         Sports with a ball    48500000          Spain
# 449    Juanpa Zurita  Cinema & Actors/actresses    28600000         Mexico
#
# ...

# %%
sorted_by_Engagement_avg_insta_df=df.sort_values(by='Engagement_avg_insta')

# %%
sorted_by_Engagement_avg_insta_df
# Out:
#                          insta_name                cat_1  insta_foll  \
# 889                 Ellen DeGeneres                Shows   116800000
# 751  Raffi Ahmad and Nagita Slavina                Shows    60600000
# 661      National Geographic Travel  Nature & landscapes    45400000
# 562                   Louis Vuitton              Fashion    47700000
# 665                             NBA   Sports with a ball    65800000
# ..                              ...                  ...         ...
# 457                        Jungkook                Music    35800000
# 903                               V                Music    38100000
# 510                         Kylie 🤍              Fashion   323300000
# 396                    JIMIN of BTS                Music    32700000
# 968                   MAKE OUT HILL                Music    20200000
#
#     Audience_insta  Authentic_insta  Engagement_avg_insta  \
# 889  United States            29200                 33300
# ...

# %%
sorted_by_Audience_Country_youtube_df=df.sort_values(by='Audience_Country_youtube')

# %%
sorted_by_Audience_Country_youtube_df
# Out:
#                      insta_name                      cat_1  insta_foll  \
# 827  Sidhu Moosewala (ਮੂਸੇ ਆਲਾ)                      Music     6900000
# 321       Giannis Antetokounmpo         Sports with a ball    12300000
# 812               icy bae 🌸✨🌱❄️  Cinema & Actors/actresses    13100000
# 676                       NJ 🇧🇷         Sports with a ball   172000000
# 57                    Ananya 💛💫  Cinema & Actors/actresses    21900000
# ..                          ...                        ...         ...
# 154                     BUGATTI          Cars & Motorbikes    16100000
# 588           Manchester United         Sports with a ball    56500000
# 590                   Måneskin                  Lifestyle     6000000
# 157               Burcu Özberk  Cinema & Actors/actresses     9000000
# 635            Miranda Cosgrove                      Music     9800000
#
#      Audience_insta  Authentic_insta  Engagement_avg_insta  \
# ...

# %%
df.head()
# Out:
#       insta_name               cat_1  insta_foll Audience_insta  \
# 0            433  Sports with a ball    48500000          Spain
# 1        TAEYANG               Music    12700000      Indonesia
# 2  НАСТЯ ИВЛЕЕВА               Shows    18800000         Russia
# 3            Joy           Lifestyle    13500000      Indonesia
# 4        Jaehyun               Music    11100000      Indonesia
#
#    Authentic_insta  Engagement_avg_insta   Tiktoker name  sub_count_tik  \
# 0           383100                637000        ekin.721         221700
# 1           478000                542300         dojacat       22200000
# 2           310800                377900     kiet.ac.quy        2100000
# 3          1100000               1400000   charlidamelio      135400000
# 4          2500000               3100000  luvadepedreiro       11400000
#
#    avg_views_tik  avg_likes_tik  Com_avg_tik  Shares_avg_tik     youtuber  \
# ...

# %%
f_top10 = df.sort_values(by=['insta_foll'], ascending=False)

# %%
f_top10
# Out:
#             insta_name               cat_1  insta_foll Audience_insta  \
# 388          Instagram         Photography   487200000          India
# 203  Cristiano Ronaldo  Sports with a ball   419600000          India
# 510            Kylie 🤍             Fashion   323300000  United States
# 532          Leo Messi  Sports with a ball   315400000      Argentina
# 814       Selena Gomez               Music   308200000  United States
# ..                 ...                 ...         ...            ...
# 255       Drew Starkey               Music     3200000  United States
# 316     GeorgeNotFound               Music     3100000  United States
# 7     설인아 sᴇᴏʀɪɴᴀ           Lifestyle     3000000    South Korea
# 337            HAECHAN               Music     2700000  United States
# 26                 NaN               Music     2600000  United States
#
#      Authentic_insta  Engagement_avg_insta     Tiktoker name  sub_count_tik  \
# ...

# %%
sns.countplot(df["Audience_insta"])
plt.xticks(rotation=80,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Audience_insta",fontsize=10)
plt.ylabel("count",fontsize=10)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df["Audience_Country_youtube"])
plt.xticks(rotation=80,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Audience_Country_youtube",fontsize=10)
plt.ylabel("count",fontsize=10)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df["cat_1"])
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("cat_1",fontsize=10)
plt.ylabel("count",fontsize=10)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df["Cat_youtube"])
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Cat_youtube	",fontsize=10)
plt.ylabel("count",fontsize=10)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
f_top10 = df.sort_values(by=['sub_count_tik'], ascending=False)
f_top10
# Out:
#               insta_name                      cat_1  insta_foll  \
# 3                    Joy                  Lifestyle    13500000
# 6     Robert Lewandowski         Sports with a ball    25000000
# 31          Akshay Kumar  Cinema & Actors/actresses    61100000
# 27          aespa 에스파                      Music     8300000
# 63        Angelina Jolie                      Music    12600000
# ..                   ...                        ...         ...
# 573        Iran Ferreira                      Music     9500000
# 750        RAFA KALIMANN                   Modeling    22800000
# 511          Song hyekyo  Cinema & Actors/actresses    12900000
# 835  숮이  💄💅👡👠🎀👙🌂👗🌂🎀💋💌         Clothing & Outfits    17500000
# 427         Jessica Jane                  Lifestyle     6000000
#
#     Audience_insta  Authentic_insta  Engagement_avg_insta   Tiktoker name  \
# 3        Indonesia          1100000               1400000   charlidamelio
# ...

# %%
f_top10 = df.sort_values(by=['cat_1'], ascending=False)
f_top10
# Out:
#            insta_name                    cat_1  insta_foll  Audience_insta  \
# 0                 433       Sports with a ball    48500000           Spain
# 785      Rohit Sharma       Sports with a ball    23300000           India
# 799        Sadio Mane       Sports with a ball    10400000  United Kingdom
# 797  Sachin Tendulkar       Sports with a ball    33500000           India
# 294      FC Barcelona       Sports with a ball   107100000       Indonesia
# ..                ...                      ...         ...             ...
# 848        Sophie Dee            Adult content    11600000   United States
# 942    Violet Summers            Adult content    13500000           Italy
# 853        Neiva Mara            Adult content    11400000          Brazil
# 645     Siew Pui Yi 🤍            Adult content    17200000   United States
# 332    Gucci Official  Accessories & Jewellery    47900000   United States
#
# ...

# %%
f_top10 = df.sort_values(by=['sub_youtube'], ascending=False)
f_top10
# Out:
#            insta_name               cat_1  insta_foll  Audience_insta  \
# 0                 433  Sports with a ball    48500000           Spain
# 1             TAEYANG               Music    12700000       Indonesia
# 2       НАСТЯ ИВЛЕЕВА               Shows    18800000          Russia
# 3                 Joy           Lifestyle    13500000       Indonesia
# 4             Jaehyun               Music    11100000       Indonesia
# ..                ...                 ...         ...             ...
# 989  Yuzvendra Chahal           Lifestyle     7500000           India
# 987           YUTA 悠太               Music     7900000       Indonesia
# 986      Caresha ..💗💋           Lifestyle     5300000   United States
# 985              KYUM               Music    10800000        Thailand
# 999         Zoë Sugg           Lifestyle     9400000  United Kingdom
#
#      Authentic_insta  Engagement_avg_insta    Tiktoker name  sub_count_tik  \
# ...
